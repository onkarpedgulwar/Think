# %% [markdown]
# # Now we will try for diffrent orientations of 1's!!!!!!!!!!!!!!!!!!!
#
# ### There are almost ten diffrent positons from which collected data for each data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data_ten1_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten1_acc.csv")
data_ten1_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten1_gyro.csv")

# %%
print(data_ten1_gyro.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  155.000000  155.000000  155.000000
# mean     0.016060   -0.001143   -0.015440
# std      0.010663    0.028186    0.009584
# min     -0.032762   -0.087555   -0.048650
# 25%      0.011987   -0.016049   -0.019832
# 50%      0.015914   -0.004818   -0.016913
# 75%      0.020324    0.004332   -0.012978
# max      0.041038    0.097059    0.017880

# %%
print(data_ten1_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  157.000000  157.000000  157.000000
# mean    -0.070663    3.524703    9.216365
# std      0.254150    0.147010    0.145941
# min     -0.991200    3.194464    8.788516
# 25%     -0.118513    3.415329    9.127894
# 50%     -0.040103    3.584120    9.221867
# 75%      0.076614    3.646968    9.270349
# max      0.456095    3.725378    9.845556

# %%
data_on_y_axis=data_ten1_acc['x-axis']
data_on_x_axis=np.arange(157)

plt.plot(data_on_x_axis,data_on_y_axis)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 1")
plt.title("one accelerometer")
plt.show()
sns.set_style('darkgrid')

# %% [markdown]
# # Now we will try for diffrent orientations of 2's!!!!!!!!!!!!!!!!!!!

# %%
data_ten2_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten2_acc.csv")
data_ten2_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten2_gyro.csv")
#description of accelerometer data
print(data_ten2_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  132.000000  132.000000  132.000000
# mean     0.311192    2.239041    9.620220
# std      0.272948    0.108177    0.127007
# min     -0.468066    1.877653    9.245210
# 25%      0.118513    2.190096    9.551069
# 50%      0.250493    2.235885    9.621398
# 75%      0.587777    2.319981    9.691130
# max      0.792481    2.452860    9.985018

# %%
#description of gyroscope data
print(data_ten2_gyro.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  129.000000  129.000000  129.000000
# mean     0.017550    0.000669   -0.014484
# std      0.018077    0.037442    0.016215
# min     -0.038692   -0.096620   -0.045819
# 25%      0.011877   -0.019086   -0.023635
# 50%      0.017162    0.001571   -0.013997
# 75%      0.028246    0.019542   -0.007535
# max      0.060573    0.095130    0.030777

# %%
data_on_y_axis_2=data_ten2_acc['x-axis']
data_on_x_axis_2=np.arange(132)

plt.plot(data_on_x_axis_2,data_on_y_axis_2)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 2")
plt.title("two accelerometer")
plt.show()
sns.set_style('darkgrid')

# %% [markdown]
# # Now we will try for diffrent orientations of 3's!!!!!!!!!!!!!!!!!!!

# %%
data_ten3_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten3_acc.csv")
data_ten3_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten3_gyro.csv")

# %%
#description of threes accelerometer data
print(data_ten3_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  111.000000  111.000000  111.000000
# mean     0.232895    2.431749    9.534746
# std      0.219988    0.094758    0.107290
# min     -0.011372    2.138022    9.144653
# 25%      0.087688    2.382530    9.469068
# 50%      0.158616    2.442086    9.547478
# 75%      0.263362    2.484583    9.607034
# max      0.767940    2.631228    9.706094

# %%
#description of threes gyroscope data
print(data_ten3_gyro.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  109.000000  109.000000  109.000000
# mean     0.012726   -0.004274   -0.013947
# std      0.010438    0.033821    0.012249
# min     -0.020120   -0.089574   -0.041683
# 25%      0.007575   -0.024690   -0.023020
# 50%      0.012288    0.005869   -0.013920
# 75%      0.017326    0.017765   -0.006696
# max      0.043494    0.062029    0.013551

# %%
data_on_y_axis_3=data_ten3_acc['x-axis']
data_on_x_axis_3=np.arange(111)

plt.plot(data_on_x_axis_3,data_on_y_axis_3)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 3")
plt.title("three accelerometer")
plt.show()
sns.set_style('darkgrid')

# %% [markdown]
# # Now we will try for diffrent orientations of 4's!!!!!!!!!!!!!!!!!!!

# %%
data_ten4_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten4_acc.csv")
data_ten4_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten4_gyro.csv")

# %%
#description of fours accelerometer data
print(data_ten4_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  101.000000  101.000000  101.000000
# mean    -0.025139    2.119491    9.646748
# std      0.401490    0.108422    0.114130
# min     -0.766145    1.787272    9.249998
# 25%     -0.424372    2.072181    9.601946
# 50%      0.213682    2.126650    9.634866
# 75%      0.260369    2.185906    9.717466
# max      0.616507    2.346318    9.940725

# %%
#description of fours gyroscope data
print(data_ten4_gyro.describe())
# Out:
#           x-axis     y-axis     z-axis
# count  99.000000  99.000000  99.000000
# mean    0.016700  -0.005196  -0.019725
# std     0.013279   0.041386   0.020952
# min    -0.017132  -0.089151  -0.070758
# 25%     0.008172  -0.030406  -0.028312
# 50%     0.017130  -0.010226  -0.016325
# 75%     0.023936   0.030925  -0.010118
# max     0.056404   0.079392   0.023202

# %%
data_on_y_axis_4=data_ten4_acc['x-axis']
data_on_x_axis_4=np.arange(101)

plt.plot(data_on_x_axis_4,data_on_y_axis_4)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 4")
plt.title("four accelerometer")
plt.show()
sns.set_style('darkgrid')

# %% [markdown]
# # Now we will try for diffrent orientations of 5's!!!!!!!!!!!!!!!!!!!

# %%
data_ten5_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten5_acc.csv")
data_ten5_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten5_gyro.csv")

# %%
#description of fivess accelerometer data
print(data_ten5_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  124.000000  124.000000  124.000000
# mean     0.289467    1.195450    9.829424
# std      0.152331    0.086861    0.084990
# min      0.074220    0.993594    9.605537
# 25%      0.158017    1.136049    9.770139
# 50%      0.296282    1.218349    9.822512
# 75%      0.363919    1.255759    9.886856
# max      0.720655    1.332972   10.037690

# %%
#description of fives accelerometer data
print(data_ten5_gyro.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  121.000000  121.000000  121.000000
# mean     0.015699   -0.000072   -0.015003
# std      0.010521    0.013648    0.004722
# min     -0.007450   -0.037824   -0.029798
# 25%      0.009962   -0.002902   -0.017659
# 50%      0.015105    0.000293   -0.013852
# 75%      0.020103    0.007214   -0.011124
# max      0.052896    0.022482   -0.007617

# %%
data_on_y_axis_5=data_ten5_acc['x-axis']
data_on_x_axis_5=np.arange(124)

plt.plot(data_on_x_axis_5,data_on_y_axis_5)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 5")
plt.title("five accelerometer")
plt.show()
sns.set_style('darkgrid')

# %% [markdown]
# # Now we will try for diffrent orientations of 6's!!!!!!!!!!!!!!!!!!!

# %%
data_ten6_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten6_acc.csv")
data_ten6_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten6_gyro.csv")

# %%
#description of six accelerometer data
print(data_ten6_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  129.000000  129.000000  129.000000
# mean     0.367719    2.171583    9.677108
# std      0.251452    0.081309    0.098646
# min      0.114922    1.838148    9.241618
# 25%      0.199916    2.126051    9.633669
# 50%      0.247201    2.185307    9.676765
# 75%      0.482432    2.224812    9.719262
# max      1.047463    2.348712    9.950302

# %%
#description of fivess gyroscope data
print(data_ten6_gyro.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  127.000000  127.000000  127.000000
# mean     0.017212   -0.001347   -0.015010
# std      0.007842    0.030620    0.008436
# min     -0.006424   -0.091563   -0.039368
# 25%      0.012856   -0.012123   -0.018868
# 50%      0.016405    0.002533   -0.014108
# 75%      0.021424    0.012999   -0.011462
# max      0.044697    0.061634    0.006192

# %%
data_on_y_axis_6=data_ten6_acc['x-axis']
data_on_x_axis_6=np.arange(129)

plt.plot(data_on_x_axis_6,data_on_y_axis_6)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 6")
plt.title("six accelerometer")
plt.show()
sns.set_style('darkgrid')

# %% [markdown]
# # Now we will try for diffrent orientations of 7's!!!!!!!!!!!!!!!!!!!

# %%
data_ten7_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten7_acc.csv")
data_ten7_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten7_gyro.csv")

# %%
#description of seven accelerometer data
print(data_ten7_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  115.000000  115.000000  115.000000
# mean     0.258553    2.168449    9.632259
# std      0.250142    0.096811    0.099932
# min     -0.529119    1.946486    9.364322
# 25%      0.239420    2.081160    9.569026
# 50%      0.317232    2.185307    9.622296
# 75%      0.416591    2.244265    9.713875
# max      0.526724    2.393005    9.844957

# %%
#description of seven gyroscope data
print(data_ten7_gyro.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  113.000000  113.000000  113.000000
# mean     0.012949    0.012059   -0.011230
# std      0.009531    0.024849    0.014272
# min     -0.017028   -0.018521   -0.042569
# 25%      0.007552   -0.003729   -0.017083
# 50%      0.013484    0.006414   -0.015052
# 75%      0.019931    0.018856   -0.009673
# max      0.032593    0.084739    0.033303

# %%
data_on_y_axis_7=data_ten7_acc['x-axis']
data_on_x_axis_7=np.arange(115)

plt.plot(data_on_x_axis_7,data_on_y_axis_7)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 7")
plt.title("seven accelerometer")
plt.show()
sns.set_style('darkgrid')

# %% [markdown]
# # Now we will try for diffrent orientations of 8's!!!!!!!!!!!!!!!!!!!

# %%
data_ten8_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten8_acc.csv")
data_ten8_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten8_gyro.csv")

# %%
#description of eight accelerometer data
print(data_ten8_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  109.000000  109.000000  109.000000
# mean     0.268941    2.231456    9.640660
# std      0.101799    0.078358    0.095456
# min      0.091578    2.103905    9.458893
# 25%      0.206500    2.169745    9.572617
# 50%      0.254384    2.221819    9.628283
# 75%      0.327407    2.288258    9.698313
# max      0.582988    2.395997   10.016742

# %%
#description of eight gyroscope data
print(data_ten8_gyro.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  107.000000  107.000000  107.000000
# mean     0.019489    0.022009   -0.012886
# std      0.008592    0.031978    0.005409
# min      0.002202   -0.021120   -0.032991
# 25%      0.013572    0.004006   -0.015789
# 50%      0.018393    0.015787   -0.012813
# 75%      0.023638    0.027866   -0.009010
# max      0.042569    0.152184   -0.002020

# %%
data_on_y_axis_8=data_ten8_acc['x-axis']
data_on_x_axis_8=np.arange(109)

plt.plot(data_on_x_axis_8,data_on_y_axis_8)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 8")
plt.title("eight accelerometer")
plt.show()
sns.set_style('darkgrid')

# %% [markdown]
# # Now we will try for diffrent orientations of 9's!!!!!!!!!!!!!!!!!!!

# %%
data_ten9_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten9_acc.csv")
data_ten9_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten9_gyro.csv")

# %%
#description of nine accelerometer data
print(data_ten9_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  116.000000  116.000000  116.000000
# mean     0.475724    2.129560    9.643514
# std      0.186578    0.118814    0.103982
# min      0.272939    1.884237    9.451710
# 25%      0.348955    2.066196    9.575011
# 50%      0.415095    2.144606    9.620501
# 75%      0.520739    2.202067    9.704897
# max      0.964863    2.366669    9.966463

# %%
#description of nine gyroscope data
print(data_ten9_gyro.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  115.000000  115.000000  115.000000
# mean     0.016145   -0.000283   -0.014050
# std      0.015837    0.020328    0.009695
# min     -0.056404   -0.071491   -0.044697
# 25%      0.010429   -0.004525   -0.018419
# 50%      0.016883    0.002738   -0.012404
# 75%      0.024140    0.010459   -0.008336
# max      0.042660    0.039348    0.002911

# %%
data_on_y_axis_9=data_ten9_acc['x-axis']
data_on_x_axis_9=np.arange(116)

plt.plot(data_on_x_axis_9,data_on_y_axis_9)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 9")
plt.title("Nine accelerometer")
plt.show()
sns.set_style('darkgrid')

# %% [markdown]
# # Now we will try for diffrent orientations of 0's!!!!!!!!!!!!!!!!!!!

# %%
data_ten0_acc=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten0_acc.csv")
data_ten0_gyro=pd.read_csv("/Users/akshaychoulwar/Desktop/Akshay/Think/ten0_gyro.csv")

# %%
#description of zero accelerometer data
print(data_ten0_acc.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  107.000000  107.000000  107.000000
# mean     0.303320    2.334990    9.610320
# std      0.228787    0.067904    0.106565
# min     -0.362123    2.155380    9.344569
# 25%      0.170886    2.289755    9.549273
# 50%      0.380678    2.333748    9.612720
# 75%      0.475848    2.391209    9.674670
# max      0.641646    2.463035    9.864710

# %%
#description of zero gyroscope data
print(data_ten0_gyro.describe())
# Out:
#            x-axis      y-axis      z-axis
# count  105.000000  105.000000  105.000000
# mean     0.031349   -0.007676   -0.008229
# std      0.018409    0.015671    0.008396
# min     -0.053211   -0.045434   -0.022724
# 25%      0.025143   -0.016772   -0.014845
# 50%      0.030134   -0.004632   -0.009405
# 75%      0.045135    0.000492   -0.003188
# max      0.060475    0.028897    0.023413

# %%
data_on_y_axis_0=data_ten0_acc['x-axis']
data_on_x_axis_0=np.arange(107)

plt.plot(data_on_x_axis_0,data_on_y_axis_0)
plt.xlabel("time sequence")
plt.ylabel("accelerometer x-axis data for 0")
plt.title("Zero accelerometer")
plt.show()
sns.set_style('darkgrid')
